# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

from sklearn.impute import KNNImputer
knn_imputer = KNNImputer(n_neighbors=5)

# %%
df = pd.read_csv("cleaned_df.csv")
df.head(2)
# Out:
#    Year  Brand             Model Body Type Drivetrain Interior Colour  \
# 0  2019  Acura  Other Model Type       SUV        AWD           Black
# 1  2022  Acura  Other Model Type       SUV        AWD             Red
#
#   Exterior Colour         Fuel Type Transmission Type  Doors  Cylinder Count  \
# 0           White  Premium Unleaded         Automatic      4             4.0
# 1           Black               Gas         Automatic      4             NaN
#
#    Fuel Efficiency (Lt/100kms)  Distance (km)  Mileage (kms/Lt)  Years Used  \
# 0                         9.92          33032              10.1           5
# 1                        11.16          31000               9.0           2
#
#    Purchase Price  Current Market Price
# 0           40888               7126.32
# 1           60899              13368.07

# %%
for col in df.select_dtypes(include='object'):
    unique_count = df[col].nunique()
    print(f'The number of unique values in the "{col}" column is: {unique_count}')
    print(df[col].value_counts())
    print("=================================================================================")
# Out:
# The number of unique values in the "Brand" column is: 21
# Brand
# Hyundai          1074
# Ford             1068
# Honda            1007
# BMW               899
# Volkswagen        776
# Other Brand       734
# Audi              709
# Nissan            671
# Mazda             626
# Chevrolet         608
# Mercedes-Benz     535
# Jeep              482
# Kia               402
# Dodge             386
# Porsche           317
# GMC               295
# Infiniti          252
# Acura             245
# Subaru            222
# Cadillac          198
# Chrysler           99
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Model" column is: 21
# Model
# Other Model Type    7186
# Civic                397
# Elantra              344
# F-150                311
# Grand                294
# Santa                248
# Q5                   239
# Jetta                230
# X5                   212
# CR-V                 211
# Mazda3               209
# Silverado            205
# Rogue                198
# Sierra               189
# Tucson               189
# Escape               183
# CX-5                 176
# X3                   159
# Tiguan               153
# Accord               148
# Wrangler             124
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Body Type" column is: 11
# Body Type
# SUV                5561
# Sedan              2964
# Coupe               642
# Hatchback           628
# Truck               421
# Minivan             387
# Crew Cab            375
# Convertible         327
# Wagon               158
# Other Body Type      85
# Compact              57
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Drivetrain" column is: 6
# Drivetrain
# AWD    5917
# FWD    3320
# 4x4    1339
# RWD     719
# 4WD     307
# 2WD       3
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Interior Colour" column is: 10
# Interior Colour
# Black           7161
# Other Colour    2556
# Grey             732
# Red              297
# Brown            240
# Beige            221
# Charcoal         163
# Tan              130
# White             69
# Cream             36
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Exterior Colour" column is: 6
# Exterior Colour
# White           3545
# Black           3190
# Other Colour    1935
# Grey            1214
# Blue            1108
# Red              613
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Fuel Type" column is: 8
# Fuel Type
# Gas                    10443
# Premium Unleaded         428
# Gasoline Hybrid          259
# Diesel                   214
# Flexible                 132
# Other                     63
# Regular Unleaded          59
# Gas/Electric Hybrid        7
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Transmission Type" column is: 3
# Transmission Type
# Automatic    9561
# Other        1487
# Manual        557
# Name: count, dtype: int64
# =================================================================================

# %% [markdown]
# ## Label Encoding Multi-Class Columns using Label Encoder:

# %%
non_numeric_columns = df.select_dtypes(exclude=['number']).columns
non_numeric_columns_list = non_numeric_columns.tolist()
print(non_numeric_columns_list)
# Out:
# ['Brand', 'Model', 'Body Type', 'Drivetrain', 'Interior Colour', 'Exterior Colour', 'Fuel Type', 'Transmission Type']

# %%
# Create a dictionary to store the mappings
mappings = {}

for col in non_numeric_columns_list:

    le.fit(df[col])
    # Store the original and encoded mappings
    mappings[col] = dict(zip(le.classes_, le.transform(le.classes_)))
    # Transform the column and assign it back to the DataFrame
    df[col] = le.transform(df[col])

# Function to reverse the encoding for a specific column
def reverse_mapping(col, value):
    return {v: k for k, v in mappings[col].items()}[value]

# %%
df
# Out:
#        Year  Brand  Model  Body Type  Drivetrain  Interior Colour  \
# 0      2019      0     10          7           3                1
# 1      2022      0     10          7           3                7
# 2      2020      0     10          7           3                1
# 3      2019      0     10          8           3                8
# 4      2020      0     10          7           3                1
# ...     ...    ...    ...        ...         ...              ...
# 11600  2011     17     10         10           4                6
# 11601  2021     17     10          7           3                1
# 11602  2022     17     10         10           3                6
# 11603  2023     17     10          7           3                3
# 11604  2021     17     10          7           3                1
#
#        Exterior Colour  Fuel Type  Transmission Type  Doors  Cylinder Count  \
# 0                    5          6                  0      4             4.0
# 1                    0          2                  0      4             NaN
# 2                    0          6                  0      4             4.0
# 3                    0          6                  0      4             6.0
# 4                    0          2                  0      4             NaN
# ...                ...        ...                ...    ...             ...
# 11600                5          2                  0      4             5.0
# 11601                5          2                  0      4             4.0
# 11602                5          2                  0      4             4.0
# 11603                5          4                  0      4             4.0
# 11604                4          2                  0      4             4.0
#
#        Fuel Efficiency (Lt/100kms)  Distance (km)  Mileage (kms/Lt)  \
# 0                             9.92          33032              10.1
# 1                            11.16          31000               9.0
# 2                            10.31          27800               9.7
# 3                             9.74          34396              10.3
# 4                             9.92          60892              10.1
# ...                            ...            ...               ...
# 11600                         8.53         206835              11.7
# 11601                         9.35          36519              10.7
# 11602                         9.59           8460              10.4
# 11603                         8.50             50              11.8
# 11604                         9.35          28154              10.7
#
#        Years Used  Purchase Price  Current Market Price
# 0               5           40888               7126.32
# 1               2           60899              13368.07
# 2               4           49099              10391.32
# 3               5           36499               6165.93
# 4               4           38495               4344.07
# ...           ...             ...                   ...
# 11600          13           11495                185.54
# 11601           3           46980               8584.23
# 11602           2           64980              31680.39
# 11603           1           82479              77965.22
# 11604           3           44980              10020.71
#
# [11605 rows x 17 columns]

# %% [markdown]
# ## Imputing Unknown values for the columns Cylinder Count having missing value % between 20-40 using KNN Imputer:

# %%
imputed_data = knn_imputer.fit_transform(df)
imputed_df = pd.DataFrame(imputed_data, columns=df.columns)
imputed_df['Cylinder Count'] = round(imputed_df['Cylinder Count'])
imputed_df.head()
# Out:
#      Year  Brand  Model  Body Type  Drivetrain  Interior Colour  \
# 0  2019.0    0.0   10.0        7.0         3.0              1.0
# 1  2022.0    0.0   10.0        7.0         3.0              7.0
# 2  2020.0    0.0   10.0        7.0         3.0              1.0
# 3  2019.0    0.0   10.0        8.0         3.0              8.0
# 4  2020.0    0.0   10.0        7.0         3.0              1.0
#
#    Exterior Colour  Fuel Type  Transmission Type  Doors  Cylinder Count  \
# 0              5.0        6.0                0.0    4.0             4.0
# 1              0.0        2.0                0.0    4.0             6.0
# 2              0.0        6.0                0.0    4.0             4.0
# 3              0.0        6.0                0.0    4.0             6.0
# 4              0.0        2.0                0.0    4.0             4.0
#
#    Fuel Efficiency (Lt/100kms)  Distance (km)  Mileage (kms/Lt)  Years Used  \
# 0                         9.92        33032.0              10.1         5.0
# 1                        11.16        31000.0               9.0         2.0
# 2                        10.31        27800.0               9.7         4.0
# 3                         9.74        34396.0              10.3         5.0
# 4                         9.92        60892.0              10.1         4.0
#
#    Purchase Price  Current Market Price
# 0         40888.0               7126.32
# 1         60899.0              13368.07
# 2         49099.0              10391.32
# 3         36499.0               6165.93
# 4         38495.0               4344.07

# %%
imputed_df.to_csv("transformed_df.csv",index=False)

# %%
# Apply the reverse mapping to the entire DataFrame
for col in non_numeric_columns_list:
    imputed_df[col] = imputed_df[col].apply(lambda x: reverse_mapping(col, x))

# %%
imputed_df.isna().sum()
# Out:
# Make                              0
# Model                             0
# Body Type                        28
# Drivetrain                        0
# Interior Colour                2508
# Exterior Colour                   0
# Fuel Type                         0
# Transmission Type                 0
# Doors                             0
# Cylinder Count                    0
# Fuel Efficiency (Lt/100kms)       0
# Distance (km)                     0
# Mileage (kms/Lt)                  0
# Years Used                        0
# Purchase Price                    0
# Current Market Price              0
# dtype: int64
