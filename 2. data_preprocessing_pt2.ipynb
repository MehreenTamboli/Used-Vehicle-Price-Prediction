# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

from sklearn.impute import KNNImputer
knn_imputer = KNNImputer(n_neighbors=5)

# %%
df = pd.read_csv("cleaned_df.csv")
df.head(2)
# Out:
#    Year  Brand             Model Body Type Drivetrain Interior Colour  \
# 0  2019  Acura  Other Model Type       SUV        AWD             Red
# 1  2018  Acura  Other Model Type       SUV        AWD           Black
#
#   Exterior Colour Fuel Type Transmission Type  Doors  Cylinder Count  \
# 0           Black       Gas         Automatic    NaN             6.0
# 1    Other Colour       Gas         Automatic    NaN             6.0
#
#    Fuel Efficiency (Lt/100kms)  Distance (km)  Mileage (kms/Lt)  Years Used  \
# 0                        10.87          53052               9.2           5
# 1                        10.98          77127               9.1           6
#
#    Price
# 0  43880
# 1  36486

# %%
for col in df.select_dtypes(include='object'):
    unique_count = df[col].nunique()
    print(f'The number of unique values in the "{col}" column is: {unique_count}')
    print(df[col].value_counts())
    print("=================================================================================")
# Out:
# The number of unique values in the "Brand" column is: 21
# Brand
# Honda            1283
# Ford             1231
# Hyundai          1223
# BMW              1099
# Nissan            952
# Other Brand       883
# Volkswagen        866
# Jeep              866
# Audi              783
# Mazda             747
# Mercedes-Benz     723
# Chevrolet         713
# Dodge             500
# Kia               497
# Porsche           431
# Infiniti          393
# GMC               347
# Subaru            299
# Acura             295
# Cadillac          216
# Chrysler          155
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Model" column is: 21
# Model
# Other Model Type    9001
# Civic                516
# Grand                424
# Elantra              381
# F-150                362
# Wrangler             291
# Santa                287
# Rogue                284
# X5                   272
# CR-V                 267
# Q5                   265
# Jetta                262
# Mazda3               247
# Silverado            245
# Sierra               221
# Tucson               217
# CX-5                 215
# Escape               204
# X3                   192
# Accord               182
# Tiguan               167
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Body Type" column is: 11
# Body Type
# SUV                7045
# Sedan              3629
# Coupe               814
# Hatchback           764
# Truck               561
# Minivan             474
# Convertible         400
# Crew Cab            396
# Wagon               225
# Other Body Type     130
# Compact              64
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Drivetrain" column is: 6
# Drivetrain
# AWD    7126
# FWD    3845
# 4x4    1556
# RWD     820
# 4WD     801
# 2WD       3
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Interior Colour" column is: 10
# Interior Colour
# Black           8410
# Other Colour    3861
# Grey             811
# Red              335
# Charcoal         305
# Brown            268
# Beige            253
# Tan              140
# White             79
# Cream             40
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Exterior Colour" column is: 6
# Exterior Colour
# White           4352
# Black           3983
# Other Colour    2559
# Grey            1526
# Blue            1339
# Red              743
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Fuel Type" column is: 10
# Fuel Type
# Gas                        12565
# Premium Unleaded             619
# Regular Unleaded             532
# Gasoline Hybrid              304
# Diesel                       255
# Flexible                     152
# Other                         65
# Gas/Electric Hybrid            8
# Gasoline Fuel                  1
# Gaseous Fuel Compatible        1
# Name: count, dtype: int64
# =================================================================================
# The number of unique values in the "Transmission Type" column is: 3
# Transmission Type
# Automatic    11706
# Other         2129
# Manual         667
# Name: count, dtype: int64
# =================================================================================

# %% [markdown]
# ## Dataset Transformation:

# %% [markdown]
# ### 1. Converting values in all the categorical columns to lowercase:

# %%
def convert_columns_to_lowercase(df):
    object_columns = df.select_dtypes(include='object').columns
    for col in object_columns:
        df[col] = df[col].apply(lambda x: x.lower() if isinstance(x, str) else x)
    return df

df = convert_columns_to_lowercase(df)
df.head()
# Out:
#        Year        Brand             Model Body Type Drivetrain  \
# 0      2019        acura  other model type       suv        awd
# 1      2018        acura  other model type       suv        awd
# 2      2019        acura  other model type       suv        awd
# 3      2020        acura  other model type       suv        awd
# 4      2021        acura  other model type       suv        awd
# ...     ...          ...               ...       ...        ...
# 14497  2011  other brand  other model type     wagon        fwd
# 14498  2021  other brand  other model type       suv        awd
# 14499  2022  other brand  other model type     wagon        awd
# 14500  2023  other brand  other model type       suv        awd
# 14501  2021  other brand  other model type       suv        awd
#
#       Interior Colour Exterior Colour         Fuel Type Transmission Type  \
# 0                 red           black               gas         automatic
# 1               black    other colour               gas         automatic
# 2               black           white  premium unleaded         automatic
# 3               black           white               gas             other
# 4                 red            blue               gas             other
# ...               ...             ...               ...               ...
# 14497    other colour           white               gas         automatic
# 14498           black           white               gas         automatic
# 14499    other colour           white               gas         automatic
# 14500        charcoal           white   gasoline hybrid         automatic
# 14501           black             red               gas         automatic
#
#        Doors  Cylinder Count  Fuel Efficiency (Lt/100kms)  Distance (km)  \
# 0        NaN             6.0                        10.87          53052
# 1        NaN             6.0                        10.98          77127
# 2        4.0             4.0                         9.92          33032
# 3        NaN             4.0                         9.92          50702
# 4        NaN             4.0                        10.31          67950
# ...      ...             ...                          ...            ...
# 14497    4.0             5.0                         8.53         206835
# 14498    4.0             4.0                         9.35          36519
# 14499    4.0             4.0                         9.59           8460
# 14500    4.0             4.0                         8.50             50
# 14501    4.0             4.0                         9.35          28154
#
#        Mileage (kms/Lt)  Years Used  Price
# 0                   9.2           5  43880
# 1                   9.1           6  36486
# 2                  10.1           5  40888
# 3                  10.1           4  44599
# 4                   9.7           3  46989
# ...                 ...         ...    ...
# 14497              11.7          13  11495
# 14498              10.7           3  46980
# 14499              10.4           2  64980
# 14500              11.8           1  82479
# 14501              10.7           3  44980
#
# [14502 rows x 16 columns]

# %% [markdown]
# ### 2. Encoding Multi-Class Categorical Columns using Label Encoder:

# %%
non_numeric_columns = df.select_dtypes(exclude=['number']).columns
non_numeric_columns_list = non_numeric_columns.tolist()
print(non_numeric_columns_list)
# Out:
# ['Brand', 'Model', 'Body Type', 'Drivetrain', 'Interior Colour', 'Exterior Colour', 'Fuel Type', 'Transmission Type']

# %%
# Create a dictionary to store the mappings
mappings = {}

for col in non_numeric_columns_list:

    le.fit(df[col])
    # Store the original and encoded mappings
    mappings[col] = dict(zip(le.classes_, le.transform(le.classes_)))
    # Transform the column and assign it back to the DataFrame
    df[col] = le.transform(df[col])

# Function to reverse the encoding for a specific column
def reverse_mapping(col, value):
    return {v: k for k, v in mappings[col].items()}[value]

# %% [markdown]
# ### 3. Imputing Unknown values for the columns 'Cylinder Count', 'Drivetran' & 'Doors' having missing value % between 0-40 using KNN Imputer:

# %%
imputed_data = knn_imputer.fit_transform(df)
imputed_df = pd.DataFrame(imputed_data, columns=df.columns)
imputed_df['Cylinder Count'] = round(imputed_df['Cylinder Count'])
imputed_df['Drivetrain'] = round(imputed_df['Drivetrain'])
imputed_df['Doors'] = round(imputed_df['Doors'])
imputed_df.head()
# Out:
#      Year  Brand  Model  Body Type  Drivetrain  Interior Colour  \
# 0  2019.0    0.0   10.0        8.0         3.0              7.0
# 1  2018.0    0.0   10.0        8.0         3.0              1.0
# 2  2019.0    0.0   10.0        8.0         3.0              1.0
# 3  2020.0    0.0   10.0        8.0         3.0              1.0
# 4  2021.0    0.0   10.0        8.0         3.0              7.0
#
#    Exterior Colour  Fuel Type  Transmission Type  Doors  Cylinder Count  \
# 0              0.0        2.0                0.0    4.0             6.0
# 1              3.0        2.0                0.0    3.0             6.0
# 2              5.0        8.0                0.0    4.0             4.0
# 3              5.0        2.0                2.0    4.0             4.0
# 4              1.0        2.0                2.0    4.0             4.0
#
#    Fuel Efficiency (Lt/100kms)  Distance (km)  Mileage (kms/Lt)  Years Used  \
# 0                        10.87        53052.0               9.2         5.0
# 1                        10.98        77127.0               9.1         6.0
# 2                         9.92        33032.0              10.1         5.0
# 3                         9.92        50702.0              10.1         4.0
# 4                        10.31        67950.0               9.7         3.0
#
#      Price
# 0  43880.0
# 1  36486.0
# 2  40888.0
# 3  44599.0
# 4  46989.0

# %%
imputed_df.to_csv(r"P:\Personal Projects\Vehicle Price Prediction\Vehicle Price Prediction\Datasets\2. imputed_df.csv",index=False)
